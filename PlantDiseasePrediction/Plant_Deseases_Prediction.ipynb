#  B-33_EC2_Q2.pdf
#  B33_EG_AutocadAssignment_S.O._AryanSawant.pdf
#  B-33_EG_Q1.pdf
#  B-33_EG_Q2.pdf
#  B-33_EG_Q3.pdf
#  B33_EM2_Tut2_AryanSawant.pdf
#  B33_ENG_PHY2_EXP1_AryanSawant.pdf
#  B33_EP2_EXP2_AryanSawant.pdf
#  B33_EP2_EXP3_AryanSawant.pdf
#  B33_EP2_EXP4_AryanSawant.pdf
#  B33_EP2_EXP5_AryanSawant.pdf
#  B-33_EP2_Q1.pdf
#  B-33_EP2_Q2.pdf
#  B33_FinalSpeechDraft_AryanSawant.pdf
#  B33_FinalSpeechPPT_AryanSawant.pptx
#  B_33_MATHSASSIGNMENT_NO2_Q1.pdf
#  B_33_MATHSASSIGNMENT_NO2_Q2.pdf
#  B_33_MATHSASSIGNMENT_NO2_Q3.pdf
#  B_33_MATHSASSIGNMENT_NO2_Q4.pdf
# 'B33_PCE_Assignment6_AryanSawant (1).pdf'
# 'B33_PCE_Assignment6_AryanSawant (2).pdf'
#  B33_PCE_Assignment6_AryanSawant.pdf
#  B33_PCE_ASSIGNMENT6_AryanSawant.pdf
#  B-33_PCE_Q1.pdf
#  B-33_PCE_Q2.pdf
#  B_33_PHY_EXP_NO1_AryanSawant.pdf
#  B_33_PHY_EXPNO2_AryanSawant.pdf
# 'B33_Physics_Exp4_AryanSawant (1).pdf'
#  B33_Physics_Exp4_AryanSawant.pdf
# 'B33_Physics_Exp5_AryanSawant(1).pdf'
#  B33_Physics_Exp5_AryanSawant.pdf
#  B33_PlagiarismReport_AryanSawant.pdf
#  B33_PlagiarismReportFinalSpeech_AryanSawant.pdf
#  B33_PracticePPT_AryanSawant.pptx
#  B33_Q2A.pdf
#  B33_Q2B.pdf
#  B33_Q2C.pdf
#  B33_Q3B.pdf
#  B33_Q3C.pdf
#  B33_Q3D.pdf
#  B33_TUT1_EM2.pdf
#  B33_Tut1_Q1.pdf
#  B33_Tut1_Q2.pdf
#  B33_Tut1_Q3.pdf
#  B_33_Tut2_Q1.pdf
#  B_33_Tut2_Q2.pdf
#  B_33_Tut2_Q3.pdf
#  B33_TUT3_EM2.pdf
# 'B41_Experiment 1.gdoc'
# 'B41_Experiment 1.odt'
# 'B41_Lexical Analyzer (1).docx'
# 'B41_Lexical Analyzer.docx'
#  B-47_AI_EXP10_AryanSawant.gdoc
#  B-47_AI_EXP1_AryanSawant.gdoc
#  B-47_AI_EXP1_AryanSawant.pdf
#  B-47_AI_EXP2_AryanSawant.gdoc
#  B-47_AI_EXP3_AryanSawant.gdoc
# 'B-47_AI_EXP4_AryanSawant (1).gdoc'
#  B-47_AI_EXP4_AryanSawant.gdoc
#  B-47_AI_EXP4_AryanSawant.pdf
#  B-47_AI_EXP5_AryanSawant.gdoc
#  B-47_AI_EXP6_AryanSawant.gdoc
#  B-47_AI_EXP7_AryanSawant.gdoc
# 'B-47_AI_EXP8_AryansSawant (1).gdoc'
#  B-47_AI_EXP8_AryansSawant.gdoc
# 'B-47_AI_EXP9_AryanSawant (1).gdoc'
#  B-47_AI_EXP9_AryanSawant.gdoc
# 'B-47_CSS_EXP10_AryanSawant (1).gdoc'
#  B-47_CSS_EXP10_AryanSawant.gdoc
#  B-47_CSS_EXP1_AryanSawant.gdoc
#  B-47_CSS_EXP2_AryanSawant.docx
#  B-47_CSS_EXP2_AryanSawant.gdoc
# 'B-47_CSS_EXP3_AryanSawant (1).gdoc'
#  B-47_CSS_EXP3_AryanSawant.gdoc
# 'B-47_CSS_EXP4_AryanSawant (1).gdoc'
# 'B-47_CSS_EXP4_AryanSawant (1).pdf'
#  B-47_CSS_EXP4_AryanSawant.gdoc
#  B-47_CSS_EXP4_AryanSawant.pdf
# 'B-47_CSS_EXP5_AryanSawant (1).gdoc'
#  B-47_CSS_EXP5_AryanSawant.gdoc
# 'B-47_CSS_EXP6_AryanSawant (1).gdoc'
# 'B-47_CSS_EXP6_AryanSawant (2).gdoc'
# 'B-47_CSS_EXP6_AryanSawant (3).gdoc'
#  B-47_CSS_EXP6_AryanSawant.gdoc
# 'B-47_CSS_EXP7_AryanSawant (1).gdoc'
#  B-47_CSS_EXP7_AryanSawant.gdoc
#  B-47_CSS_EXP8_AryanSawant.gdoc
#  B-47_CSS_EXP9_AryanSawant.gdoc
# 'B47_Expt9_AI_AryanSawant (1).gdoc'
#  B47_Expt9_AI_AryanSawant.gdoc
#  B-47_MC_EXP10_AryanSawant.gdoc
#  B-47_MC_EXP3_AryanSawant.gdoc
#  B-47_MC_EXP4_AryanSawant.gdoc
#  B-47_MC_EXP5_AryanSawant.gdoc
#  B-47_MC_EXP6_AryanSawant.gdoc
#  B-47_MC_EXP8_AryanSawant.gdoc
#  B-47_MC_EXP9_AryanSawant.gdoc
#  B-47_SBL_EXP1_REPORT_AryanSawant.gdoc
#  B-47_SBL_EXP2_AryanSawant.gdoc
# 'B-47_SBL_EXP3_AryanSawant (1).gdoc'
#  B-47_SBL_EXP3_AryanSawant.gdoc
#  B-47_SBL_EXP4_AryanSawant.gdoc
#  B-47_SBL_EXP5_AryanSawant.gdoc
# 'B-47_SBL_EXP6_AryanSawant (1).gdoc'
#  B-47_SBL_EXP6_AryanSawant.gdoc
#  B-47_SBL_EXP7_AryanSawant.gdoc
# 'B-47_SBL_EXP8_AryanSawant (1).gdoc'
#  B-47_SBL_EXP8_AryanSawant.gdoc
#  B-47_SBL_EXP8_AryanSawant.pdf
#  B-47_SBL_EXP9_AryanSawant.gdoc
#  B-47_SPCC_EXP1_AryanSawant.gdoc
#  B-47_SPCC_EXP2_AryanSawant.docx
#  B-47_SPCC_EXP2_AryanSawant.gdoc
#  B-47_SPCC_EXP3_AryanSawant.gdoc
#  B-47_SPCC_EXP5_AryanSawant.gdoc
#  B-47_SPCC_EXP6_AryanSawant.gdoc
#  B-47_SPCC_EXP7_AryanSawant.gdoc
#  B-47_SPCC_EXP8_AryanSawant.gdoc
#  B-47_SPCC_EXP9_AryanSawant.gdoc
#  B48_Expt9_AI.odt
#  B-48_IP_ASSIGNMENT2_AryanSawant.pdf
# 'B-48_TBL_AryanSawant (1).pdf'
#  B-48_TBL_AryanSawant.pdf
#  CG_TT1_B28.pdf
#  Classroom
# 'Cloud computing 2022-23- Lab manual.gdoc'
# 'Coconut_tree_project_documentation (1).docx'
# 'Coconut_tree_project_documentation (2).docx'
#  Coconut_tree_project_documentation.docx
# 'Colab Notebooks'
# 'COVID 1st Dose.pdf'
# 'Database Management system  Lab manual Final.gdoc'
# 'Data Structure_Module2.3.gslides'
# 'DDOS Attacks And Countermeasures.pptx'
#  DLCA_TT1_B28.pdf
# 'DSGT IA 1.pdf'
#  DS_TT1_B28_AryanSawant.pdf
#  dwm3.gdoc
#  EBSCO
#  Enhancement_of_security_in_visual_cryptography_system_using_cover_image_share_embedded_security_algorithm_CISEA.gdoc
#  Enhancement_of_security_in_visual_cryptography_system_using_cover_image_share_embedded_security_algorithm_CISEA.pdf
#  Essay.gdoc
# 'EXP 2_B-33_AryanSawant.pdf'
# 'EXP2_CSS_Kaustubh Raut.gdoc'
# 'FE_B33_PhysicsProject_AryanSawant (1).pdf'
#  FE_B33_PhysicsProject_AryanSawant.pdf
#  IA2-CP-B-33.pdf
#  IA2-EC2-B-33.pdf
#  IA2_EG_AUTOCAD_B_33.pdf
#  IA2-EM2-B-33.pdf
#  IA2-EP2-B-33.pdf
#  IA2-PCE-B-33.pdf
#  identity.gdoc
# 'IMG_20210422_143051 (1).jpg'
#  IMG_20210422_143051.jpg
#  IMG_20220611_214538.jpg
#  IMG_20230208_125559.pdf
#  IMG_20230208_130021.pdf
# 'Intechposter  (1).gslides'
# 'Introduction to Machine Learning with Python A Guide for Data Scientists (Andreas C. Müller, Sarah Guido) (z-lib.org).pdf'
# 'IP EXPERIMENT  9.gdoc'
# 'java cover page.gdoc'
# 'Lab manual_CN (1).gdoc'
# 'Lab manual_CN.gdoc'
#  lec1.gdoc
#  Makefile
#  mc.gdoc
#  mc.pdf
#  MC_PPT_IA.gslides
# 'MC sample questions.gdoc'
# 'Mini PROJECT REPORT_sem 5.docx'
#  MinorAssets
# 'minor_project_report_sem 5.docx'
# 'minor_project_report_sem 5.gdoc'
# 'MinorProjectSEM6 (1).pptx'
# 'MinorProjectSEM6 (1).pptx - Pie chart 1.gsheet'
# 'MinorProjectSEM6 (2).pptx'
#  MinorProjectSEM6.pptx
# 'Module_6_Applications of AI (1).gsheet'
# 'Module_6_Applications of AI (2).gsheet'
# 'Module_6_Applications of AI.gsheet'
# 'PDF.js viewer (1).gdoc'
# 'PDF.js viewer.gdoc'
# 'PDF.js viewer.pdf'
# 'PHP calculator code (1).gdoc'
# 'PHP calculator code (2).gdoc'
# 'PHP calculator code.gdoc'
#  plant_disease.h5
#  Plant_images_pianalytix
#  plant_model.json
#  plant_model_weights.h5
# 'ppt-format 2022.gslides'
#  Print….pdf
#  Project.gslides
# 'PROJECT REPORT for Internship.gdoc'
# 'Python Experiment 1.gdoc'
#  Q1_AME-1_TT1_B28.pdf
#  Q1_AME-1_TT2_B28.pdf
#  Q1_CG_TT2_B28.pdf
#  Q1_DLCA_TT2_B28.pdf
#  Q1_DS_TT2_B28.pdf
#  Q2_AME-1_TT1_B28.pdf
#  Q2_AME-1_TT2_B28.pdf
#  Q2_CG_TT2_B28.pdf
#  Q2_DLCA_TT2_B28.pdf
#  Q2_DS_TT2_B28.pdf
#  Q3_AME-1_TT1_B28.pdf
#  Q3_AME-1_TT2_B28.pdf
#  Q3_CG_TT2_B28.pdf
#  Q3_DLCA_TT2_B28.pdf
#  Q3_DS_TT2_B28.pdf
#  QA_IA_PPT.gslides
#  Resume
# 'Screenshot_2021-04-05-15-12-34-979_com (1).android.chrome.doc'
#  Screenshot_2021-04-05-15-12-34-979_com.android.chrome.doc
# 'Screenshot_2021-08-21-21-28-20-625_com (1).android.chrome.jpg'
#  Screenshot_2021-08-21-21-28-20-625_com.android.chrome.jpg
#  Screenshot_2023-04-05-21-37-25-548_com.google.android.apps.nbu.paisa.user.jpg
#  Screenshot_2023-05-22-13-40-39-540_com.google.android.apps.nbu.paisa.user.jpg
# 'Signature (1).pdf'
# 'Signature (2).pdf'
# 'Signature (3).pdf'
# 'Signature (4).pdf'
# 'Signature (5).pdf'
# 'Signature (6).pdf'
# 'Signature (7).pdf'
# 'Signature (8).pdf'
# 'Signature (9).pdf'
#  Signature.pdf
#  TBL_REPORT.gdoc
#  tmp-cam-424141246.jpg
#  try.png
#  TY_MinorProject_ReportFormat_Autonomus_2022.gdoc
#  UNIT-3.gslides
# 'Untitled document (1).gdoc'
# 'Untitled document - Bar chart 1.gsheet'
# 'Untitled document.gdoc'
# 'Untitled document.pdf'
# 'WhatsApp Image 2022-02-11 at 8.53.35 PM.jpeg'
# 'WI PPT.gslides'

# %% [markdown]
# After mounting our drive we will locate the folder where our data is stored to use it in our colab notebook.
# Here you can see that I have 2 folders in my drive and 'Plant_images_pianlytix'  contains the images that we will work on.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.image import imread
import cv2
import random
import os
from os import listdir
from PIL import Image
from sklearn.preprocessing import label_binarize,  LabelBinarizer
from keras.preprocessing import image
from tensorflow.keras.utils import img_to_array, array_to_img
#from keras.preprocessing.image import img_to_array, array_to_img
from keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Flatten, Dropout, Dense
from sklearn.model_selection import train_test_split
from keras.models import model_from_json
from keras.utils import to_categorical

# %% [markdown]
# Next we will import all the required libraries. As we are making a CNN model we will import all the required layers, activations, optimizers, etc.

# %%
# Plotting 12 images to check dataset
plt.figure(figsize=(12,12))
path = "/content/drive/My Drive/Plant_images_pianalytix/Potato___Early_blight"
for i in range(1,17):
    plt.subplot(4,4,i)
    plt.tight_layout()
    rand_img = imread(path +'/'+ random.choice(sorted(os.listdir(path))))
    plt.imshow(rand_img)
    plt.xlabel(rand_img.shape[1], fontsize = 10)#width of image
    plt.ylabel(rand_img.shape[0], fontsize = 10)#height of image

# %% [markdown]
# Now we will observe some of the iamges that are their in our dataset. We will plot 12 images here using the matplotlib library.

# %%
#Converting Images to array 
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, (256,256))  
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) 
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %% [markdown]
# After visualizing the images let us move forward and create a function which will convert the images into a numpy array. It is required because we will normalize our dataset after this.

# %%
dir = "/content/drive/My Drive/Plant_images_pianalytix"
root_dir = listdir(dir)
image_list, label_list = [], []
all_labels = ['Corn-Common_rust', 'Potato-Early_blight', 'Tomato-Bacterial_spot']
binary_labels = [0,1,2]
temp = -1

# Reading and converting image to numpy array
for directory in root_dir:
  plant_image_list = listdir(f"{dir}/{directory}")
  temp += 1
  for files in plant_image_list:
    image_path = f"{dir}/{directory}/{files}"
    image_list.append(convert_image_to_array(image_path))
    label_list.append(binary_labels[temp])

# %% [markdown]
# Now we will convert all the images into numpy array.

# %%
# Visualize the number of classes count
label_counts = pd.DataFrame(label_list).value_counts()
label_counts.head()
# Out:
# 0    300
# 1    300
# 2    300
# dtype: int64

# %% [markdown]
# We will also observe the number of images under different classes to see if the dataset is balanced or not

# %%
image_list[0].shape
# Out:
# (256, 256, 3)

# %% [markdown]
# Next we will observe the shape of the image.

# %%
label_list = np.array(label_list)
label_list.shape
# Out:
# (900,)

# %% [markdown]
# Checking the total number of the images which is the length of the labels list.

# %%
x_train, x_test, y_train, y_test = train_test_split(image_list, label_list, test_size=0.2, random_state = 10)

# %% [markdown]
# Next we will use sklearn train_test_split to split the dataset into testing and training data. Here I have taken test size as 0.2 so my data will be divided into 80% training and 20% testing data.

# %%
x_train = np.array(x_train, dtype=np.float16) / 225.0
x_test = np.array(x_test, dtype=np.float16) / 225.0
x_train = x_train.reshape( -1, 256,256,3)
x_test = x_test.reshape( -1, 256,256,3)

# %% [markdown]
# Now we will normalize the dataset of our images. As pixel values ranges from 0 to 255 so we will divide each image pixel with 255 to normalize the dataset.

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), padding="same",input_shape=(256,256,3), activation="relu"))
model.add(MaxPooling2D(pool_size=(3, 3)))
model.add(Conv2D(16, (3, 3), padding="same", activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(8, activation="relu"))
model.add(Dense(3, activation="softmax"))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 256, 256, 32)      896
#
#  max_pooling2d_2 (MaxPooling  (None, 85, 85, 32)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 85, 85, 16)        4624
#
#  max_pooling2d_3 (MaxPooling  (None, 42, 42, 16)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 28224)             0
#
#  dense_2 (Dense)             (None, 8)                 225800
#
#  dense_3 (Dense)             (None, 3)                 27
#
# =================================================================
# Total params: 231,347
# Trainable params: 231,347
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Next we will create a network architecture for the model. We have used different types of layers according to their features namely Conv_2d (It is used to create a convolutional kernel that is convolved with the input layer to produce the output tensor), max_pooling2d (It is a downsampling technique which takes out the maximum value over the window defined by poolsize), flatten (It flattens the input and creates a 1D output), Dense (Dense layer produce the output as the dot product of input and kernel).

# %%
model.compile(loss = 'categorical_crossentropy', optimizer = Adam(0.0001),metrics=['accuracy'])

# %% [markdown]
# While compiling the model we need to set the type of loss which will be Binary Crossentropy for our model alongwith this we also need to set the optimizer and the metrics respectively.

# %%
# Splitting the training data set into training and validation data sets
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.2)

# %% [markdown]
# Next we will split the dataset into validation and training data.

# %%
# Training the model
epochs = 50
batch_size = 128
history = model.fit(x_train, y_train, batch_size = batch_size, epochs = epochs, 
                    validation_data = (x_val, y_val))
# Out:
# Epoch 1/50
# 5/5 [==============================] - 2s 270ms/step - loss: 1.0329 - accuracy: 0.4167 - val_loss: 0.9403 - val_accuracy: 0.6458
# Epoch 2/50
# 5/5 [==============================] - 1s 170ms/step - loss: 0.8983 - accuracy: 0.6441 - val_loss: 0.8021 - val_accuracy: 0.6597
# Epoch 3/50
# 5/5 [==============================] - 1s 230ms/step - loss: 0.7551 - accuracy: 0.6615 - val_loss: 0.6573 - val_accuracy: 0.8472
# Epoch 4/50
# 5/5 [==============================] - 1s 212ms/step - loss: 0.6113 - accuracy: 0.9201 - val_loss: 0.5340 - val_accuracy: 0.9444
# Epoch 5/50
# 5/5 [==============================] - 1s 214ms/step - loss: 0.4908 - accuracy: 0.9427 - val_loss: 0.4258 - val_accuracy: 0.9375
# Epoch 6/50
# 5/5 [==============================] - 1s 153ms/step - loss: 0.3930 - accuracy: 0.9479 - val_loss: 0.3452 - val_accuracy: 0.9514
# Epoch 7/50
# 5/5 [==============================] - 1s 151ms/step - loss: 0.3165 - accuracy: 0.9462 - val_loss: 0.2884 - val_accuracy: 0.9514
# Epoch 8/50
# 5/5 [==============================] - 1s 147ms/step - loss: 0.2611 - accuracy: 0.9497 - val_loss: 0.2430 - val_accuracy: 0.9583
# Epoch 9/50
# 5/5 [==============================] - 1s 148ms/step - loss: 0.2167 - accuracy: 0.9531 - val_loss: 0.2125 - val_accuracy: 0.9653
# Epoch 10/50
# 5/5 [==============================] - 1s 152ms/step - loss: 0.1847 - accuracy: 0.9601 - val_loss: 0.1910 - val_accuracy: 0.9583
# Epoch 11/50
# 5/5 [==============================] - 1s 147ms/step - loss: 0.1683 - accuracy: 0.9497 - val_loss: 0.1867 - val_accuracy: 0.9583
# Epoch 12/50
# 5/5 [==============================] - 1s 149ms/step - loss: 0.1498 - accuracy: 0.9618 - val_loss: 0.1613 - val_accuracy: 0.9653
# Epoch 13/50
# 5/5 [==============================] - 1s 145ms/step - loss: 0.1309 - accuracy: 0.9618 - val_loss: 0.1585 - val_accuracy: 0.9583
# Epoch 14/50
# 5/5 [==============================] - 1s 144ms/step - loss: 0.1226 - accuracy: 0.9566 - val_loss: 0.1473 - val_accuracy: 0.9653
# Epoch 15/50
# 5/5 [==============================] - 1s 145ms/step - loss: 0.1118 - accuracy: 0.9722 - val_loss: 0.1382 - val_accuracy: 0.9722
# Epoch 16/50
# 5/5 [==============================] - 1s 151ms/step - loss: 0.1040 - accuracy: 0.9635 - val_loss: 0.1357 - val_accuracy: 0.9653
# Epoch 17/50
# 5/5 [==============================] - 1s 148ms/step - loss: 0.0940 - accuracy: 0.9705 - val_loss: 0.1279 - val_accuracy: 0.9722
# Epoch 18/50
# 5/5 [==============================] - 1s 150ms/step - loss: 0.0896 - accuracy: 0.9757 - val_loss: 0.1250 - val_accuracy: 0.9653
# Epoch 19/50
# 5/5 [==============================] - 1s 149ms/step - loss: 0.0805 - accuracy: 0.9757 - val_loss: 0.1197 - val_accuracy: 0.9653
# Epoch 20/50
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0764 - accuracy: 0.9844 - val_loss: 0.1116 - val_accuracy: 0.9722
# Epoch 21/50
# 5/5 [==============================] - 1s 225ms/step - loss: 0.0687 - accuracy: 0.9913 - val_loss: 0.1082 - val_accuracy: 0.9722
# Epoch 22/50
# 5/5 [==============================] - 1s 228ms/step - loss: 0.0623 - accuracy: 0.9861 - val_loss: 0.1045 - val_accuracy: 0.9722
# Epoch 23/50
# 5/5 [==============================] - 1s 220ms/step - loss: 0.0584 - accuracy: 0.9896 - val_loss: 0.1068 - val_accuracy: 0.9722
# Epoch 24/50
# 5/5 [==============================] - 1s 145ms/step - loss: 0.0569 - accuracy: 0.9896 - val_loss: 0.0971 - val_accuracy: 0.9722
# Epoch 25/50
# 5/5 [==============================] - 1s 144ms/step - loss: 0.0540 - accuracy: 0.9931 - val_loss: 0.0951 - val_accuracy: 0.9722
# Epoch 26/50
# 5/5 [==============================] - 1s 153ms/step - loss: 0.0481 - accuracy: 0.9896 - val_loss: 0.0870 - val_accuracy: 0.9792
# Epoch 27/50
# 5/5 [==============================] - 1s 145ms/step - loss: 0.0428 - accuracy: 0.9931 - val_loss: 0.0839 - val_accuracy: 0.9792
# Epoch 28/50
# 5/5 [==============================] - 1s 145ms/step - loss: 0.0415 - accuracy: 0.9948 - val_loss: 0.0833 - val_accuracy: 0.9861
# Epoch 29/50
# 5/5 [==============================] - 1s 150ms/step - loss: 0.0375 - accuracy: 0.9931 - val_loss: 0.0771 - val_accuracy: 0.9792
# Epoch 30/50
# 5/5 [==============================] - 1s 152ms/step - loss: 0.0333 - accuracy: 0.9965 - val_loss: 0.0787 - val_accuracy: 0.9861
# Epoch 31/50
# 5/5 [==============================] - 1s 153ms/step - loss: 0.0323 - accuracy: 0.9948 - val_loss: 0.0717 - val_accuracy: 0.9861
# Epoch 32/50
# 5/5 [==============================] - 1s 154ms/step - loss: 0.0287 - accuracy: 0.9965 - val_loss: 0.0736 - val_accuracy: 0.9861
# Epoch 33/50
# 5/5 [==============================] - 1s 152ms/step - loss: 0.0262 - accuracy: 0.9983 - val_loss: 0.0706 - val_accuracy: 0.9861
# Epoch 34/50
# 5/5 [==============================] - 1s 152ms/step - loss: 0.0242 - accuracy: 0.9983 - val_loss: 0.0687 - val_accuracy: 0.9861
# Epoch 35/50
# 5/5 [==============================] - 1s 153ms/step - loss: 0.0223 - accuracy: 0.9983 - val_loss: 0.0681 - val_accuracy: 0.9861
# Epoch 36/50
# 5/5 [==============================] - 1s 151ms/step - loss: 0.0209 - accuracy: 0.9983 - val_loss: 0.0665 - val_accuracy: 0.9861
# Epoch 37/50
# 5/5 [==============================] - 1s 198ms/step - loss: 0.0191 - accuracy: 0.9983 - val_loss: 0.0722 - val_accuracy: 0.9861
# Epoch 38/50
# 5/5 [==============================] - 1s 193ms/step - loss: 0.0186 - accuracy: 0.9983 - val_loss: 0.0645 - val_accuracy: 0.9861
# Epoch 39/50
# 5/5 [==============================] - 1s 219ms/step - loss: 0.0174 - accuracy: 0.9983 - val_loss: 0.0655 - val_accuracy: 0.9861
# Epoch 40/50
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0164 - accuracy: 0.9983 - val_loss: 0.0643 - val_accuracy: 0.9861
# Epoch 41/50
# 5/5 [==============================] - 1s 182ms/step - loss: 0.0158 - accuracy: 0.9983 - val_loss: 0.0658 - val_accuracy: 0.9861
# Epoch 42/50
# 5/5 [==============================] - 1s 154ms/step - loss: 0.0145 - accuracy: 1.0000 - val_loss: 0.0668 - val_accuracy: 0.9861
# Epoch 43/50
# 5/5 [==============================] - 1s 147ms/step - loss: 0.0134 - accuracy: 1.0000 - val_loss: 0.0652 - val_accuracy: 0.9861
# Epoch 44/50
# 5/5 [==============================] - 1s 145ms/step - loss: 0.0127 - accuracy: 1.0000 - val_loss: 0.0679 - val_accuracy: 0.9861
# Epoch 45/50
# 5/5 [==============================] - 1s 154ms/step - loss: 0.0117 - accuracy: 1.0000 - val_loss: 0.0644 - val_accuracy: 0.9861
# Epoch 46/50
# 5/5 [==============================] - 1s 145ms/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.0679 - val_accuracy: 0.9861
# Epoch 47/50
# 5/5 [==============================] - 1s 152ms/step - loss: 0.0107 - accuracy: 1.0000 - val_loss: 0.0640 - val_accuracy: 0.9861
# Epoch 48/50
# 5/5 [==============================] - 1s 151ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.0625 - val_accuracy: 0.9861
# Epoch 49/50
# 5/5 [==============================] - 1s 147ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.0664 - val_accuracy: 0.9861
# Epoch 50/50
# 5/5 [==============================] - 1s 140ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.0632 - val_accuracy: 0.9861

# %% [markdown]
# Fitting the model with the data and finding out the accuracy at each epoch to see how our model is learning. Now we will train our model on 10 epochs and a batch size of 128. You can try using more number of epochs to increase accuracy but here we can see that the model has already raeched a very high accuracy so we don't need to run it for more. During each epochs we can see how the model is performing by viewing the training and validation accuracy.

# %%
model.save("/content/drive/My Drive/plant_disease.h5")
# serialize model to json
json_model = model.to_json()
#save the model architecture to JSON file
with open('/content/drive/My Drive/plant_model.json', 'w') as json_file:
    json_file.write(json_model)
#saving the weights of the model
model.save_weights('/content/drive/My Drive/plant_model_weights.h5')

# %% [markdown]
# Saving the model using different techniques.

# %%
#Plot the training history
plt.figure(figsize=(12, 5))
plt.plot(history.history['accuracy'], color='r')
plt.plot(history.history['val_accuracy'], color='b')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])

plt.show()

# %% [markdown]
# Next we will plot the accuracy of the model for the trainig history.

# %%
print("[INFO] Calculating model accuracy")
scores = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# [INFO] Calculating model accuracy
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0702 - accuracy: 0.9778
# Test Accuracy: 97.77777791023254

# %% [markdown]
# Evaluating the model to know the accuracy of the model.

# %%
y_pred = model.predict(x_test)
# Out:
# 6/6 [==============================] - 0s 16ms/step

# %% [markdown]
# Next we will use our model to predict predicting the testing dataset label.

# %%
# Plotting image to compare
img = array_to_img(x_test[10])
img
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FD5C973B9D0>

# %%
# Finding max value from predition list and comaparing original value vs predicted
print("Originally : ",all_labels[np.argmax(y_test[10])])
print("Predicted : ",all_labels[np.argmax(y_pred[10])])
# Out:
# Originally :  Potato-Early_blight
# Predicted :  Potato-Early_blight

# %% [markdown]
# Printing out the original and the predicted label.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# We started with loading the dataset into google colab using google drive and visualizing the images. Normalizing is an important step when working with any type of dataset. After that we created a CNN Model which is further used for predicting the plant diseases using the image supplied to model.
# This model is highly beneficial as it can be used by different agricultural firms and farmers to increase their yield and stop wastage of crops due to disease.

# %%
from tensorflow.keras.models import load_model
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-46-279f716a8fb0> in <cell line: 2>()
#       1 from google.colab import files
# ----> 2 files.download("model1.h5")
#
# /usr/local/lib/python3.10/dist-packages/google/colab/files.py in download(filename)
#     220   if not _os.path.exists(filename):
#     221     msg = 'Cannot find file: {}'.format(filename)
# --> 222     raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     223
#     224   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# FileNotFoundError: Cannot find file: model1.h5
